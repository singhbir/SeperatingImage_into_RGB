# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
imgx=cv2.imread("/home/spidee/Documents/BIR/he.png")

# %%
plt.imshow(imgx)

# %%
(h,w,_)=imgx.shape

# %%
red=imgx[:,:,0]

# %%
green=imgx[:,:,1]

# %%
black=np.ones([675,w*3])

# %%
plt.imshow(black)

# %%
black[:,0:w]=black[:,0:w]*red
black[:,w:w*2]=black[:,w:w*2]*green

# %%
plt.imshow(black)

# %%
black[:,w*2:w*3]=black[:,w*2:w*3]*imgx[:,:,2]

# %%
plt.imshow(black)

# %%
imgx.shape
# Out:
# (675, 1214, 3)
